# %%
# DICTONARY: this is a collection of keys:values pairs.
# key and value is seperated by :(colan), seperated by comma(,)
# all pairs are enclosed by{}
# keys are unique values, values can be any
# it access values based on key
# syntax----> variable[key]

# %%
d1={}
print(type(d1))
# Out:
# <class 'dict'>

# %%
d2=dict()
print(type(d2))
# Out:
# <class 'dict'>

# %%
#access value
student={"name":"amit","age":21, "city":"rcpm"}
student["name"]
# Out:
# 'amit'

# %%
student["age"]
# Out:
# 21

# %%
student["city"]
# Out:
# 'rcpm'

# %%
#update
student.update({"grade":"A"})
student
# Out:
# {'name': 'amit', 'age': 21, 'city': 'rcpm', 'grade': 'A'}

# %%
#popitem------> it defaultly remove last element
student.popitem()
student
# Out:
# {'name': 'amit', 'age': 21, 'city': 'rcpm'}

# %%
#pop
student.pop("age")
student
# Out:
# {'name': 'amit', 'city': 'rcpm'}

# %%
#delete
student.delete("city")
student
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 #delete
# ----> 2 student.delete("city")
#       3 student
#
# AttributeError: 'dict' object has no attribute 'delete'

# %%
# clear------> it shows empty braces
student.clear()
student
# Out:
# {}

# %%
# check name in student
"name" in student
# Out:
# False

# %%
#keys-----> gives tuple
d1={1:"divya",2:"mohan"}
d1.keys()
# Out:
# dict_keys([1, 2])

# %%
d1.values()
# Out:
# dict_values(['divya', 'mohan'])

# %%
d1.items()
# Out:
# dict_items([(1, 'divya'), (2, 'mohan')])

# %%
len(d1)
# Out:
# 2

# %%
d1={1:"divya",2:"mohan"}
d1.clear()
d1
# Out:
# {}
