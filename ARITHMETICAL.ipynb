# %%
# ADDITION

# %%
a=10
b=13
sum=a+b
sum
# Out:
# 23

# %%
# substraction

# %%
a=int(input("value 1 = "))
b=int(input("value 2 = "))
sub=a-b
sub
# Out:
# value 1 =  9
# value 2 =  8
# 1

# %%
# multiplication

# %%
num1=int(input("enter your value"))
num2=int(input("enter your value"))
mul=num1*num2
mul
# Out:
# enter your value 21
# enter your value 12
# 252

# %%
# division(float)

# %%
value1=int(input("v1"))
value2=int(input("v2"))
division=value1/value2
division
# Out:
# v1 19
# v2 2
# 9.5

# %%
a1=20
a2=30
quotient=a1//a2
quotient
# Out:
# 0

# %%
#%percent

# %%
b1=50
b2=30
percentage=b1%b2
percentage
# Out:
# 20

# %%
# power/ exponents

# %%
m=3
n=4
power=m**n
power
# Out:
# 81
