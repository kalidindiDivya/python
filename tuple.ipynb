# %%
# TUPLE: tple is a immutable ordered collection of elements.
# tuples are smililar to lists, but unlike lists, they cannot be changed after the creation
# it can hold elements of different data types
# these are ordered, hoimogenous and heterogenous and immutable
#a tuple is created by placing all the items inside parantheses(), seperated be commas(,). it can have any number of items

# %%
t1=()
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t2=tuple()
print(type(t2))
# Out:
# <class 'tuple'>

# %%
# using string
tuple=("divya","mohan")
tuple
# Out:
# ('divya', 'mohan')

# %%
L1=[1,4,6,8]
print(tuple(L1))
# Out:
# (1, 4, 6, 8)

# %%
# USING BUILT-IN FUNCTION
name="rcpm"
print (tuple(name))
# Out:
# ('r', 'c', 'p', 'm')

# %%
# creating a tuple with mixed data types

#Tuple can store elements of different data types, such as integers, string, list and dictonaries, with in a single structre

tup=(5,"divya",1.0,True,[2,5,9], {'key':'value'})
print(tup)
# Out:
# (5, 'divya', 1.0, True, [2, 5, 9], {'key': 'value'})

# %%
t2 = (1,3,6,9,10,13,15)
t2[4]
# Out:
# 10

# %%
t3=("divya","is","sweet")
a,b,c=t3
print(a)
print(b)
print(c)
# Out:
# divya
# is
# sweet

# %%
t4=("divya","is","sweet")
t4[1]
# Out:
# 'is'

# %%
# concatination of tuples: tuples can be concatinated using the + operator. this operation is used to combine two or more tuples to create a new tuple
# note: only tuples can be concatinated by tuples.
tup1=(1,2,3,4)
tup2=("divya","is","sweet")
tup3= tup1+tup2
print(tup3)
# Out:
# (1, 2, 3, 4, 'divya', 'is', 'sweet')

# %%
# slicing of tuple: it means creating a new tuple fron a subset of element of the original tuple. 
# syntax: ([start:end:step])
name=("divyaisbeautiful")
print(tuple(name))
# Out:
# ('d', 'i', 'v', 'y', 'a', 'i', 's', 'b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l')

# %%
t4=(1,3,8,15,20,25,14,20)
t4[-1]
# Out:
# 20

# %%
t4[5]
# Out:
# 25

# %%
t4[2:5]
# Out:
# (8, 15, 20)

# %%
# delete---> tuples are immutable, we cant delete individual elemetns of a tuple, we can delete entire tuple by using del statement
tup=(0,1,2,3)
del tup
print(tup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       2 tup=(0,1,2,3)
#       3 del tup
# ----> 4 print(tup)
#
# NameError: name 'tup' is not defined

# %%
# sorted
t4=(10,1,4,12,20,11,9,99,45)
sorted(t4)
# Out:
# [1, 4, 9, 10, 11, 12, 20, 45, 99]

# %%
sorted(t4,reverse=True)
# Out:
# [99, 45, 20, 12, 11, 10, 9, 4, 1]

# %%
t4.index(99)
# Out:
# 7

# %%
t4.count(45)
# Out:
# 1

# %%
t5=(10,1,4,11,20,11,9,99,45)
t5.count(11)
# Out:
# 2
