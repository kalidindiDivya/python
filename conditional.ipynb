# %%
#conditional statement is used to make decisions in a program , if the condition is true,do it .. otherwise dont do

# %%
# check the major or minor with age

# %%
age=int(input("enter your age"))
if(age>=18):
    print("your are mojar")
else:
    print("your are minor")
# Out:
# enter your age 30
# your are mojar

# %%
# check positive, negative and zero

# %%
num=float(input("enter number"))
if(num>0):
    print(num, " number is postive")
elif(num<0):
    print(num, "number is  negative")
else:
    print("number is zero")
# Out:
# enter number 0
# number is zero

# %%
# check leap year

#rule 1= divisible by 400 leap year
#rule 2= divisible by 4 but not divisible by 100= leap year

# %%
year=int(input("enter  year"))
if(year%400==0) or (year%4==0)and (year%100 !=0):
    print(year, "is a leap year  ")
else:
    print(year, "is not a leap year")
# Out:
# enter  year 2013
# 2013 is not a leap year

# %%
# simple calculator

# %%
a=float(input("enter first number"))
b=float(input("enter second number"))
operator=input("enter operator + - * / : ")
if(operator=="+"):
    print(" Result:", a+b)
elif(operator == "-"):
    print("Result:", a-b)
elif(operator == " * "):
    print("result:", a*b)
elif(operator == "/"):
    print("Result:", a/b)
else:
    print("invalid operator")
# Out:
# enter first number 4
# enter second number 3
# enter operator + - * / :  +
#  Result: 7.0

# %%
# character check

# %%
ch=input("enter your character")
if (ch.isupper()):
    print(" upper case letter")
elif(ch.islower()):
    print("lower case letter")
elif(ch.isdigit()):
    print("Digit")
else:
    print(" special character")
# Out:
# enter your character $
#  special character
